# %%
# configura el ancho de la página
from IPython.display import clear_output, display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# # [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# **Es un lenguaje marcado de escritura breve para la publicación de texto en html. Se puede utilizar para la publicación de manera consistente en [internet](https://markdown.es).**
#
# **Existen diferentes versiones de *Markdown* por lo que no hay un estándar. A pesar de esto se darán unos comandos básicos para su uso.**
# ### Comandos, consultar la página del [github](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) para más información
#
# ---
# ---

# %% [markdown]
# # <font color = limegreen>Formato básico:<font>

# %% [markdown]
# ### Cursiva usando `*` y `_` en los extremos de la palabra o frase

# %% [markdown]
# _Saccharomyces cereviciae_ es una levadura, ...
#
# *Saccharomyces cereviciae* es una levadura, ...

# %% [markdown]
# ### Negritas usando `**` en los extremos de la palabra o frase

# %% [markdown]
# **_Saccharomyces cereviciae_** es una levadura, ...

# %% [markdown]
# ### En texto simple al final de cada fila agregar `dos espacios` y dar enter para no juntar las líneas

# %% [markdown]
# ### Remarcar código

# %% [markdown]
# Para ver una lista de archivos ejecuta la función `os.listdir()`

# %% [markdown]
# `Para ver una lista de archivos ejecuta la función os.listdir()`

# %% [markdown]
# #### otra forma de mostrar código
#
# ```python
# for i in range(10):
#     print(i)
#
# ```

# %% [markdown]
# # <font color = limegreen>Encabezados:<font>

# %% [markdown]
# ```
# # E1
# ## E2
# ### E3
# #### E4
# ##### E5
# ###### E6
# ```

# %% [markdown]
# # <font color = limegreen>Listas:<font>

# %% [markdown]
# ### Para crear listas desordenadas utiliza `*` asteriscos, `-` guiones, o `+` símbolo de suma.

# %% [markdown]
# ## Título
# - Subtítulo 1
# - Subtítulo 2
#     - Sub-lemento 1
#     - Sub-lemento 2
#         - Subsub-elemento 1
#         - Subsub-elemento 2
#             - Subsubsub-

# %% [markdown]
# ### Para crear listas ordenadas debes utilizar la sintaxis de tipo: “número.” `1.`. Al igual que ocurre con las listas desordenadas, también podrás anidarlas o combinarlas.

# %% [markdown]
# ## Título
# 1. Elemento 1 de lista
# 2. Elemento 2 de lista
#     - Elemento 2.1 de lista
#     - Elemento 2.2 de lista
#         1. Elemento 2.2.1 de sublista
#         2. Elemento 2.2.2 de sublista
# 3. Elemento 3 de lista
# 4. Elemento 4 de lista

# %% [markdown]
# Se pueden mezclar distintos tipos de listas y anidar unas dentro de otras.
#
# 1. Esto es una lista ordenada
# 2. Segundo elemento de la lista ordenada
#     1. Esta es una lista ordenada anidada dentro de otra
#         * Lista desordenada anidada a tercer nivel
#         * Segundo elemento de esta lista
#     2. Este es el segundo elemento de la lista ordenada anidada

# %% [markdown]
# # <font color = limegreen>Visualización de imágenes:<font>

# %% [markdown]
# ### Desde la red
#
# #### Comando
#
# `<img style="float: left;" src="https://almablog-media.s3.ap-south-1.amazonaws.com/Frame_47_min_b472e0bbd0.png" width = 30%> <br>`

# %% [markdown]
# ### [Julia](https://julialang.org)
# <img style="float: left;" src="https://almablog-media.s3.ap-south-1.amazonaws.com/Frame_47_min_b472e0bbd0.png" width = 30%> <br>

# %% [markdown]
# ### [Julia](https://julialang.org)
# <img style="float: center;" src="https://almablog-media.s3.ap-south-1.amazonaws.com/Frame_47_min_b472e0bbd0.png" width = 30%> <br>

# %% [markdown]
# ### [Julia](https://julialang.org)
# <img style="float: right;" src="https://almablog-media.s3.ap-south-1.amazonaws.com/Frame_47_min_b472e0bbd0.png" width = 30%>
